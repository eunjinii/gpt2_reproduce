# %%
from transformers import GPT2LMHeadModel

# %%
model_hf = GPT2LMHeadModel.from_pretrained("gpt2")
sd_hf = model_hf.state_dict()

for k, v in sd_hf.items():
    print(k, v.shape)
# Out:
# transformer.wte.weight torch.Size([50257, 768])
# transformer.wpe.weight torch.Size([1024, 768])
# transformer.h.0.ln_1.weight torch.Size([768])
# transformer.h.0.ln_1.bias torch.Size([768])
# transformer.h.0.attn.c_attn.weight torch.Size([768, 2304])
# transformer.h.0.attn.c_attn.bias torch.Size([2304])
# transformer.h.0.attn.c_proj.weight torch.Size([768, 768])
# transformer.h.0.attn.c_proj.bias torch.Size([768])
# transformer.h.0.ln_2.weight torch.Size([768])
# transformer.h.0.ln_2.bias torch.Size([768])
# transformer.h.0.mlp.c_fc.weight torch.Size([768, 3072])
# transformer.h.0.mlp.c_fc.bias torch.Size([3072])
# transformer.h.0.mlp.c_proj.weight torch.Size([3072, 768])
# transformer.h.0.mlp.c_proj.bias torch.Size([768])
# transformer.h.1.ln_1.weight torch.Size([768])
# transformer.h.1.ln_1.bias torch.Size([768])
# transformer.h.1.attn.c_attn.weight torch.Size([768, 2304])
# transformer.h.1.attn.c_attn.bias torch.Size([2304])
# ...

# %%
sd_hf["transformer.wpe.weight"].view(-1)[:20]
# Out:
# tensor([-0.0188, -0.1974,  0.0040,  0.0113,  0.0638, -0.1050,  0.0369, -0.1680,
#         -0.0491, -0.0565, -0.0025,  0.0135, -0.0042,  0.0151,  0.0166, -0.1381,
#         -0.0063, -0.0461,  0.0267, -0.2042])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(sd_hf["transformer.wpe.weight"], cmap="gray")

# %%
plt.plot(sd_hf["transformer.wpe.weight"][:, 150])
plt.plot(sd_hf["transformer.wpe.weight"][:, 200])
plt.plot(sd_hf["transformer.wpe.weight"][:, 250])

# %%
plt.imshow(sd_hf["transformer.h.1.attn.c_attn.weight"][:50, :50], cmap="gray")

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)

generator("Hello, I'm a language model, ", max_length=30, num_return_sequences=5)
# Out:
# 2024-12-02 11:23:15.915356: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-02 11:23:15.936032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-02 11:23:15.957368: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-02 11:23:15.963691: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r') as f:
    text = f.read()
data = text[:1000] # first 1,000 characters
print(data[:100])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %%
import tiktoken
enc = tiktoken.get_encoding('gpt2')
tokens = enc.encode(data)
print(tokens[:24])
# Out:
# [5962, 22307, 25, 198, 8421, 356, 5120, 597, 2252, 11, 3285, 502, 2740, 13, 198, 198, 3237, 25, 198, 5248, 461, 11, 2740, 13]

# %%
import torch
buf = torch.tensor(tokens[:24 + 1])
x = buf[:-1].view(4, 6)
y = buf[1:].view(4, 6)
print(x)
print(y)
# Out:
# tensor([[ 5962, 22307,    25,   198,  8421,   356],
#         [ 5120,   597,  2252,    11,  3285,   502],
#         [ 2740,    13,   198,   198,  3237,    25],
#         [  198,  5248,   461,    11,  2740,    13]])
# tensor([[22307,    25,   198,  8421,   356,  5120],
#         [  597,  2252,    11,  3285,   502,  2740],
#         [   13,   198,   198,  3237,    25,   198],
#         [ 5248,   461,    11,  2740,    13,   198]])

# %%
print(sd_hf["lm_head.weight"].shape)
print(sd_hf["transformer.wte.weight"].shape)
# Out:
# torch.Size([50257, 768])
# torch.Size([50257, 768])

# %%
(sd_hf["lm_head.weight"] == sd_hf["transformer.wte.weight"]).all()
# Out:
# tensor(True)

# %%
print(sd_hf["lm_head.weight"].data_ptr())
print(sd_hf["transformer.wte.weight"].data_ptr())
# Out:
# 157113984
# 157113984

# %%
# parse and visualize the logfile
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sz = "124M"

loss_baseline = {
    "124M": 3.2924,
}[sz]
hella2_baseline = { # HellaSwag for GPT-2
    "124M": 0.294463,
    "350M": 0.375224,
    "774M": 0.431986,
    "1558M": 0.488946,
}[sz]
hella3_baseline = { # HellaSwag for GPT-3
    "124M": 0.337,
    "350M": 0.436,
    "774M": 0.510,
    "1558M": 0.547,
}[sz]

def parse_log_file(filename):
    with open(filename, "r") as f:
        lines = f.readlines()
    streams = {}
    for line in lines:
        step, stream, val = line.strip().split()
        if stream not in streams:
            streams[stream] = {}
        streams[stream][int(step)] = float(val)
    return streams

def streams_to_xy(streams):
    streams_xy = {}
    for k, v in streams.items():
        # get all (step, val) items, sort them
        xy = sorted(list(v.items()))
        # unpack the list of tuples to tuple of lists
        streams_xy[k] = list(zip(*xy))
    return streams_xy

# Load and parse the log files
streams_nanogpt = parse_log_file("log_nanogpt/log.txt")
streams_diffattn = parse_log_file("log_diffattn/log.txt")

# Convert each stream from {step: val} to (steps[], vals[])
streams_nanogpt_xy = streams_to_xy(streams_nanogpt)
streams_diffattn_xy = streams_to_xy(streams_diffattn)

# Create figure
plt.figure(figsize=(16, 6))

# Panel 1: losses - both train and val
plt.subplot(121)
# Plot nanogpt train loss
if "train" in streams_nanogpt_xy:
    xs, ys = streams_nanogpt_xy["train"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f'nanogpt ({sz}) train loss')
    print("Nanogpt Min Train Loss:", min(ys))
# Plot diffattn train loss
if "train" in streams_diffattn_xy:
    xs, ys = streams_diffattn_xy["train"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f'diffattn ({sz}) train loss')
    print("DiffAttn Min Train Loss:", min(ys))
# Plot nanogpt val loss
if "val" in streams_nanogpt_xy:
    xs, ys = streams_nanogpt_xy["val"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f'nanogpt ({sz}) val loss')
    print("Nanogpt Min Validation Loss:", min(ys))
# Plot diffattn val loss
if "val" in streams_diffattn_xy:
    xs, ys = streams_diffattn_xy["val"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f'diffattn ({sz}) val loss')
    print("DiffAttn Min Validation Loss:", min(ys))
# Horizontal line at GPT-2 baseline
if loss_baseline is not None:
    plt.axhline(y=loss_baseline, color='r', linestyle='--', label=f"OpenAI GPT-2 ({sz}) checkpoint val loss")
plt.xlabel("steps")
plt.ylabel("loss")
plt.yscale('log')
plt.legend()
plt.title("Loss")

# Panel 2: HellaSwag eval
plt.subplot(122)
# Plot nanogpt HellaSwag eval
if "hella" in streams_nanogpt_xy:
    xs, ys = streams_nanogpt_xy["hella"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f"nanogpt ({sz})")
    print("Nanogpt Max Hellaswag eval:", max(ys))
# Plot diffattn HellaSwag eval
if "hella" in streams_diffattn_xy:
    xs, ys = streams_diffattn_xy["hella"]
    ys = np.array(ys)
    plt.plot(xs, ys, label=f"diffattn ({sz})")
    print("DiffAttn Max Hellaswag eval:", max(ys))
# Horizontal lines at GPT-2 and GPT-3 baselines
if hella2_baseline:
    plt.axhline(y=hella2_baseline, color='r', linestyle='--', label=f"OpenAI GPT-2 ({sz}) checkpoint")
if hella3_baseline:
    plt.axhline(y=hella3_baseline, color='g', linestyle='--', label=f"OpenAI GPT-3 ({sz}) checkpoint")
plt.xlabel("steps")
plt.ylabel("accuracy")
plt.legend()
plt.title("HellaSwag eval")
# Out:
# Nanogpt Min Train Loss: 2.897868
# DiffAttn Min Train Loss: 5.433028
# Nanogpt Min Validation Loss: 3.0685
# DiffAttn Min Validation Loss: 5.65
# Nanogpt Max Hellaswag eval: 0.3076
# DiffAttn Max Hellaswag eval: 0.2547
# Text(0.5, 1.0, 'HellaSwag eval')
